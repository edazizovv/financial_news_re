# %%
#

# %%
import json
import time
import numpy
import pandas
import datetime
from scipy import stats
from data.flat import load
from matplotlib import pyplot
from matplotlib import lines as mlines
# Out:
# E:\venv\financial_news_re\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
# from mpydge.wrap.models.linear import XBR
from xgboost import XGBRegressor as XBR

# %%
from m_utils.measures import r2_adj
from m_utils.sampling import ts_sampler
from m_utils.feature_selection import recursive_batch

# %%
# models
# all of them are stored in .json file with possible parameters

import json

with open('./models_params.json') as f:
    models_params = json.load(f)

# %%
def multiply_params(params):
    keys = numpy.array(list(params.keys()))
    dims = numpy.array([len(params[keys[j]]) for j in numpy.arange(keys.shape[0])])
    result = []
    for j in numpy.arange(dims.prod()):
        curr = j
        res = {}
        for k in numpy.arange(keys.shape[0]):
            ix = curr % dims[k]
            res[keys[k]] = params[keys[k]][ix]
            curr = curr // dims[k]
        result.append(res)
    return result

# %%
dim_models = 0
multiple_model_args = multiply_params(models_params['XGBRegressor'])
multiple_model_args
# Out:
# [{'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.0},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.1,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.25,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.1},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
# ...
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.75,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 0.9,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 1.0,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.1,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.5,
#   'n_jobs': -1,
#   'subsample': 0.95,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 10,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 50,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  {'n_estimators': 200,
#   'learning_rate': 0.01,
#   'n_jobs': -1,
#   'subsample': 0.9,
#   'reg_alpha': 1.0,
#   'reg_lambda': 0.5},
#  ...]

# %%
def load_data(data, tsi_names, y_names, removes, test_rate, n_folds):

    # clarify names

    exclude = y_names + removes
    x_names = [x for x in data.columns.values if (x not in exclude and 'LAG0' not in x)]
    
    # sample (without folds)

    data_train, data_test = ts_sampler(data, n_folds, test_rate)
    X_, Y_ = numpy.array(x_names), numpy.array(y_names)
    X_train, Y_train = [x[X_].values for x in data_train], [x[Y_].values for x in data_train]
    X_test, Y_test = data_test[X_].values, data_test[Y_].values
    
    print('Fold shape: {0}'.format(X_train[0].shape))
    print('Test shape: {0}'.format(X_test.shape))
    
    return X_train, Y_train, X_test, Y_test, X_

# %%
def golags(tsi_names, y_names, removes, test_rate=0.2, n_folds=1):
    report = pandas.DataFrame(columns=['Np', 'Nf', 'R2_adj_train', 'R2_adj_test', 'd1', 'params', 'd1', 'X_adj_'])
    X_train, Y_train, X_test, Y_test, X_ = load_data(data, tsi_names, y_names, removes, test_rate, n_folds)
    model = XBR

    verbose_step = 100
    n_iters = len(multiple_model_args)
    print('N of expected iters = {0}'.format(n_iters))
    print('Started search: {0}'.format(datetime.datetime.now().isoformat()))
    
    for i in range(len(multiple_model_args)):

        if i % verbose_step == 0:
            print('{0} / {1}'.format(i, n_iters))
            
        params = multiple_model_args[i]
        
        for j in range(len(X_train)):
            
            model_ = model(**params)
            model_.fit(X_train[j], Y_train[j].ravel())
            Y_hat_train = model_.predict(X_train[j])
            Y_hat_test = model_.predict(X_test)
            result = {'Np': i, 'Nf': j, 
                      'R2_adj_train': r2_adj(Y_train[j], Y_hat_train, X_train[j].shape[0], X_train[j].shape[1]),
                      'R2_adj_test': r2_adj(Y_test, Y_hat_test, X_test.shape[0], X_test.shape[1]),
                      'd1': X_train[j].shape[1], 'params': params, 'X_adj_': X_}
            
            report = report.append(result, ignore_index=True)

    print('Finished search: {0}'.format(datetime.datetime.now().isoformat()))
    
    return report

# %%
d = './dataset.csv'
data = pandas.read_csv(d)
data = data.rename(columns={'lag': 'news_horizon'})
data = data.set_index(['ticker', 'time', 'news_horizon'], drop=False)
data = data.sort_index()
data
# Out:
#                                               ticker  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3              MSFT
#                                  3              MSFT
#                                  6              MSFT
#                                  6              MSFT
#                                  9              MSFT
# ...                                              ...
#        2019-09-26 20:00:00+00:00 94             MSFT
#                                  94             MSFT
#                                  94             MSFT
#                                  94             MSFT
#                                  97             MSFT
#
#                                                                     time  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             2019-08-30 15:08:00+00:00
#                                  3             2019-08-30 15:08:00+00:00
#                                  6             2019-08-30 15:08:00+00:00
#                                  6             2019-08-30 15:08:00+00:00
#                                  9             2019-08-30 15:08:00+00:00
# ...                                                                  ...
#        2019-09-26 20:00:00+00:00 94            2019-09-26 20:00:00+00:00
#                                  94            2019-09-26 20:00:00+00:00
#                                  94            2019-09-26 20:00:00+00:00
#                                  94            2019-09-26 20:00:00+00:00
#                                  97            2019-09-26 20:00:00+00:00
#
#                                                open_LAG0  close_LAG0  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             -0.000292   -0.000438
#                                  3             -0.000292   -0.000438
#                                  6             -0.000292   -0.000438
#                                  6             -0.000292   -0.000438
#                                  9             -0.000292   -0.000438
# ...                                                  ...         ...
#        2019-09-26 20:00:00+00:00 94            -0.000072    0.000716
#                                  94            -0.000072    0.000716
#                                  94            -0.000072    0.000716
#                                  94            -0.000072    0.000716
#                                  97            -0.000072    0.000716
#
#                                                high_LAG0  low_LAG0  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             -0.000365 -0.000511
#                                  3             -0.000365 -0.000511
#                                  6             -0.000365 -0.000511
#                                  6             -0.000365 -0.000511
#                                  9             -0.000365 -0.000511
# ...                                                  ...       ...
#        2019-09-26 20:00:00+00:00 94            -0.000215  0.000933
#                                  94            -0.000215  0.000933
#                                  94            -0.000215  0.000933
#                                  94            -0.000215  0.000933
#                                  97            -0.000215  0.000933
#
#                                                volume_LAG0  open_LAG1  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                0.539497  -0.000146
#                                  3                0.539497  -0.000146
#                                  6                0.539497  -0.000146
#                                  6                0.539497  -0.000146
#                                  9                0.539497  -0.000146
# ...                                                    ...        ...
#        2019-09-26 20:00:00+00:00 94               4.762202   0.000932
#                                  94               4.762202   0.000932
#                                  94               4.762202   0.000932
#                                  94               4.762202   0.000932
#                                  97               4.762202   0.000932
#
#                                                close_LAG1  high_LAG1  ...  \
# ticker time                      news_horizon                         ...
# MSFT   2019-08-30 15:08:00+00:00 3              -0.000219  -0.000292  ...
#                                  3              -0.000219  -0.000292  ...
#                                  6              -0.000219  -0.000292  ...
#                                  6              -0.000219  -0.000292  ...
#                                  9              -0.000219  -0.000292  ...
# ...                                                   ...        ...  ...
#        2019-09-26 20:00:00+00:00 94              0.000143   0.001218  ...
#                                  94              0.000143   0.001218  ...
#                                  94              0.000143   0.001218  ...
#                                  94              0.000143   0.001218  ...
#                                  97              0.000143   0.001218  ...
#
#                                                volume_LAG99  open_LAG100  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                 9.611399    -0.000359
#                                  3                 9.611399    -0.000359
#                                  6                 9.611399    -0.000359
#                                  6                 9.611399    -0.000359
#                                  9                 9.611399    -0.000359
# ...                                                     ...          ...
#        2019-09-26 20:00:00+00:00 94               -0.407206     0.000644
#                                  94               -0.407206     0.000644
#                                  94               -0.407206     0.000644
#                                  94               -0.407206     0.000644
#                                  97               -0.407206     0.000644
#
#                                                close_LAG100  high_LAG100  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                 0.000647    -0.000072
#                                  3                 0.000647    -0.000072
#                                  6                 0.000647    -0.000072
#                                  6                 0.000647    -0.000072
#                                  9                 0.000647    -0.000072
# ...                                                     ...          ...
#        2019-09-26 20:00:00+00:00 94               -0.000143     0.000215
#                                  94               -0.000143     0.000215
#                                  94               -0.000143     0.000215
#                                  94               -0.000143     0.000215
#                                  97               -0.000143     0.000215
#
#                                                low_LAG100  volume_LAG100  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                0.00036      18.300000
#                                  3                0.00036      18.300000
#                                  6                0.00036      18.300000
#                                  6                0.00036      18.300000
#                                  9                0.00036      18.300000
# ...                                                   ...            ...
#        2019-09-26 20:00:00+00:00 94               0.00043       0.827525
#                                  94               0.00043       0.827525
#                                  94               0.00043       0.827525
#                                  94               0.00043       0.827525
#                                  97               0.00043       0.827525
#
#                                                    id  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             165358
#                                  3             165350
#                                  6             165205
#                                  6             165253
#                                  9             165103
# ...                                               ...
#        2019-09-26 20:00:00+00:00 94            383553
#                                  94            383482
#                                  94            383461
#                                  94            383481
#                                  97            383371
#
#                                                                                            title  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             From Jedis to astronauts: How NASA tapped a vi...
#                                  3             How About a Mash Up of Green Bonds and Century...
#                                  6             Brexit endgame: It's PM Johnson vs parliament ...
#                                  6             The Latest: Scottish court moves up case on UK...
#                                  9             Deutsche Post sees interest from potential Str...
# ...                                                                                          ...
#        2019-09-26 20:00:00+00:00 94            Timeline: The alarming pattern of actions by T...
#                                  94            UK royals give Boaty McBoatface polar ship its...
#                                  94            UPDATE 1-Unipec replaces ship charters after U...
#                                  94            Ukrainian leader's rivals use Trump call to ki...
#                                  97            Pelosi on Trump whistleblower complaint: 'This...
#
#                                                news_horizon  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                        3
#                                  3                        3
#                                  6                        6
#                                  6                        6
#                                  9                        9
# ...                                                     ...
#        2019-09-26 20:00:00+00:00 94                      94
#                                  94                      94
#                                  94                      94
#                                  94                      94
#                                  97                      97
#
#                                                                news_time
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             2019-08-30 15:05:00+00:00
#                                  3             2019-08-30 15:05:00+00:00
#                                  6             2019-08-30 15:02:00+00:00
#                                  6             2019-08-30 15:02:00+00:00
#                                  9             2019-08-30 14:59:00+00:00
# ...                                                                  ...
#        2019-09-26 20:00:00+00:00 94            2019-09-26 18:26:00+00:00
#                                  94            2019-09-26 18:26:00+00:00
#                                  94            2019-09-26 18:26:00+00:00
#                                  94            2019-09-26 18:26:00+00:00
#                                  97            2019-09-26 18:23:00+00:00
#
# [163925 rows x 511 columns]

# %%
tsi_names = ['news_time']
y_names = ['open_LAG0']
removes = ['ticker', 'time', 'id', 'title', 'news_time']

report = golags(tsi_names, y_names, removes, n_folds=5)
report
# Out:
# Fold shape: (21483, 501)
# Test shape: (36978, 501)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-5a71d7ca5c2b> in <module>
#       3 removes = ['ticker', 'time', 'id', 'title', 'news_time']
#       4
# ----> 5 report = golags(tsi_names, y_names, removes, n_folds=5)
#       6 report
#
# <ipython-input-10-1a1415aa9cbb> in golags(tsi_names, y_names, removes, test_rate, n_folds)
#      11
#      12             model_ = model(**params)
# ---> 13             model_.fit(X_train[j], Y_train[j].ravel())
#      14             Y_hat_train = model_.predict(X_train[j])
#      15             Y_hat_test = model_.predict(X_test)
#
# E:\venv\financial_news_re\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     537                 params.update({'eval_metric': eval_metric})
#     538
# --> 539         self._Booster = train(params, train_dmatrix,
#     540                               self.get_num_boosting_rounds(), evals=evals,
#     541                               early_stopping_rounds=early_stopping_rounds,
#
# E:\venv\financial_news_re\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     206         callbacks.append(callback.record_evaluation(evals_result))
#     207
# --> 208     return _train_internal(params, dtrain,
#     209                            num_boost_round=num_boost_round,
#     210                            evals=evals,
#
# E:\venv\financial_news_re\lib\site-packages\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      73         # Skip the first update if it is a recovery step.
#      74         if version % 2 == 0:
# ---> 75             bst.update(dtrain, i, obj)
#      76             bst.save_rabit_checkpoint()
#      77             version += 1
#
# E:\venv\financial_news_re\lib\site-packages\xgboost\core.py in update(self, dtrain, iteration, fobj)
#    1365
#    1366         if fobj is None:
# -> 1367             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1368                                                     ctypes.c_int(iteration),
#    1369                                                     dtrain.handle))
#
# KeyboardInterrupt:
