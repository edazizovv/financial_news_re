# %%
#

# %%
import json
import time
import numpy
import pandas
from scipy import stats
from data.flat import load
from matplotlib import pyplot
from matplotlib import lines as mlines

# %%
# from mpydge.wrap.models.linear import RFR
from sklearn.ensemble import RandomForestRegressor as RFR

# %%
from m_utils.measures import r2_adj
from m_utils.sampling import ts_sampler
from m_utils.feature_selection import recursive_batch

# %%
# models
# all of them are stored in .json file with possible parameters

import json

with open('./models_params.json') as f:
    models_params = json.load(f)

# %%
def multiply_params(params):
    keys = numpy.array(list(params.keys()))
    dims = numpy.array([len(params[keys[j]]) for j in numpy.arange(keys.shape[0])])
    result = []
    for j in numpy.arange(dims.prod()):
        curr = j
        res = {}
        for k in numpy.arange(keys.shape[0]):
            ix = curr % dims[k]
            res[keys[k]] = params[keys[k]][ix]
            curr = curr // dims[k]
        result.append(res)
    return result

# %%
dim_models = 0
multiple_model_args = multiply_params(models_params['RandomForestRegressor'])
multiple_model_args
# Out:
# [{'n_estimators': 10, 'max_depth': None, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 50, 'max_depth': None, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 100,
#   'max_depth': None,
#   'max_features': 'auto',
#   'n_jobs': -1},
#  {'n_estimators': 200,
#   'max_depth': None,
#   'max_features': 'auto',
#   'n_jobs': -1},
#  {'n_estimators': 500,
#   'max_depth': None,
#   'max_features': 'auto',
#   'n_jobs': -1},
#  {'n_estimators': 1000,
#   'max_depth': None,
#   'max_features': 'auto',
#   'n_jobs': -1},
#  {'n_estimators': 10, 'max_depth': 10, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 50, 'max_depth': 10, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 100, 'max_depth': 10, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 200, 'max_depth': 10, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 500, 'max_depth': 10, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 1000, 'max_depth': 10, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 10, 'max_depth': 5, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 50, 'max_depth': 5, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 100, 'max_depth': 5, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 200, 'max_depth': 5, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 500, 'max_depth': 5, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 1000, 'max_depth': 5, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 10, 'max_depth': 2, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 50, 'max_depth': 2, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 100, 'max_depth': 2, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 200, 'max_depth': 2, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 500, 'max_depth': 2, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 1000, 'max_depth': 2, 'max_features': 'auto', 'n_jobs': -1},
#  {'n_estimators': 10, 'max_depth': None, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 50, 'max_depth': None, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 100,
#   'max_depth': None,
#   'max_features': 'sqrt',
#   'n_jobs': -1},
#  {'n_estimators': 200,
#   'max_depth': None,
#   'max_features': 'sqrt',
#   'n_jobs': -1},
#  {'n_estimators': 500,
#   'max_depth': None,
#   'max_features': 'sqrt',
#   'n_jobs': -1},
#  {'n_estimators': 1000,
#   'max_depth': None,
#   'max_features': 'sqrt',
#   'n_jobs': -1},
#  {'n_estimators': 10, 'max_depth': 10, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 50, 'max_depth': 10, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 100, 'max_depth': 10, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 200, 'max_depth': 10, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 500, 'max_depth': 10, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 1000, 'max_depth': 10, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 10, 'max_depth': 5, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 50, 'max_depth': 5, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 100, 'max_depth': 5, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 200, 'max_depth': 5, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 500, 'max_depth': 5, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 1000, 'max_depth': 5, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 10, 'max_depth': 2, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 50, 'max_depth': 2, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 100, 'max_depth': 2, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 200, 'max_depth': 2, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 500, 'max_depth': 2, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 1000, 'max_depth': 2, 'max_features': 'sqrt', 'n_jobs': -1},
#  {'n_estimators': 10, 'max_depth': None, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 50, 'max_depth': None, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 100,
#   'max_depth': None,
#   'max_features': 'log2',
#   'n_jobs': -1},
#  {'n_estimators': 200,
#   'max_depth': None,
#   'max_features': 'log2',
#   'n_jobs': -1},
#  {'n_estimators': 500,
#   'max_depth': None,
#   'max_features': 'log2',
#   'n_jobs': -1},
#  {'n_estimators': 1000,
#   'max_depth': None,
#   'max_features': 'log2',
#   'n_jobs': -1},
#  {'n_estimators': 10, 'max_depth': 10, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 50, 'max_depth': 10, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 100, 'max_depth': 10, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 200, 'max_depth': 10, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 500, 'max_depth': 10, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 1000, 'max_depth': 10, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 10, 'max_depth': 5, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 50, 'max_depth': 5, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 100, 'max_depth': 5, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 200, 'max_depth': 5, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 500, 'max_depth': 5, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 1000, 'max_depth': 5, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 10, 'max_depth': 2, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 50, 'max_depth': 2, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 100, 'max_depth': 2, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 200, 'max_depth': 2, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 500, 'max_depth': 2, 'max_features': 'log2', 'n_jobs': -1},
#  {'n_estimators': 1000, 'max_depth': 2, 'max_features': 'log2', 'n_jobs': -1}]

# %%
def load_data(data, tsi_names, y_names, removes, test_rate, n_folds):

    # clarify names

    exclude = y_names + removes
    x_names = [x for x in data.columns.values if (x not in exclude and 'LAG0' not in x)]
    
    # sample (without folds)

    data_train, data_test = ts_sampler(data, n_folds, test_rate)
    X_, Y_ = numpy.array(x_names), numpy.array(y_names)
    X_train, Y_train = [x[X_].values for x in data_train], [x[Y_].values for x in data_train]
    X_test, Y_test = data_test[X_].values, data_test[Y_].values
    
    print('Fold shape: {0}'.format(X_train[0].shape))
    print('Test shape: {0}'.format(X_test.shape))
    
    return X_train, Y_train, X_test, Y_test, X_

# %%
def golags(tsi_names, y_names, removes, test_rate=0.2, n_folds=1):
    report = pandas.DataFrame(columns=['Np', 'Nf', 'R2_adj_train', 'R2_adj_test', 'd1', 'params', 'd1', 'X_adj_'])
    X_train, Y_train, X_test, Y_test, X_ = load_data(data, tsi_names, y_names, removes, test_rate, n_folds)
    model = RFR
    
    for i in range(len(multiple_model_args)):
        
        params = multiple_model_args[i]
        
        for j in range(len(X_train)):
            
            model_ = model(**params)
            model_.fit(X_train[j], Y_train[j].ravel())
            Y_hat_train = model_.predict(X_train[j])
            Y_hat_test = model_.predict(X_test)
            result = {'Np': i, 'Nf': j, 
                      'R2_adj_train': r2_adj(Y_train[j], Y_hat_train, X_train[j].shape[0], X_train[j].shape[1]),
                      'R2_adj_test': r2_adj(Y_test, Y_hat_test, X_test.shape[0], X_test.shape[1]),
                      'd1': X_train[j].shape[1], 'params': params, 'X_adj_': X_}
            
            report = report.append(result, ignore_index=True)

    return report

# %%
d = './dataset.csv'
data = pandas.read_csv(d)
data = data.rename(columns={'lag': 'news_horizon'})
data = data.set_index(['ticker', 'time', 'news_horizon'], drop=False)
data = data.sort_index()
data
# Out:
#                                               ticker  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3              MSFT
#                                  3              MSFT
#                                  6              MSFT
#                                  6              MSFT
#                                  9              MSFT
# ...                                              ...
#        2019-09-26 20:00:00+00:00 94             MSFT
#                                  94             MSFT
#                                  94             MSFT
#                                  94             MSFT
#                                  97             MSFT
#
#                                                                     time  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             2019-08-30 15:08:00+00:00
#                                  3             2019-08-30 15:08:00+00:00
#                                  6             2019-08-30 15:08:00+00:00
#                                  6             2019-08-30 15:08:00+00:00
#                                  9             2019-08-30 15:08:00+00:00
# ...                                                                  ...
#        2019-09-26 20:00:00+00:00 94            2019-09-26 20:00:00+00:00
#                                  94            2019-09-26 20:00:00+00:00
#                                  94            2019-09-26 20:00:00+00:00
#                                  94            2019-09-26 20:00:00+00:00
#                                  97            2019-09-26 20:00:00+00:00
#
#                                                open_LAG0  close_LAG0  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             -0.000292   -0.000438
#                                  3             -0.000292   -0.000438
#                                  6             -0.000292   -0.000438
#                                  6             -0.000292   -0.000438
#                                  9             -0.000292   -0.000438
# ...                                                  ...         ...
#        2019-09-26 20:00:00+00:00 94            -0.000072    0.000716
#                                  94            -0.000072    0.000716
#                                  94            -0.000072    0.000716
#                                  94            -0.000072    0.000716
#                                  97            -0.000072    0.000716
#
#                                                high_LAG0  low_LAG0  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             -0.000365 -0.000511
#                                  3             -0.000365 -0.000511
#                                  6             -0.000365 -0.000511
#                                  6             -0.000365 -0.000511
#                                  9             -0.000365 -0.000511
# ...                                                  ...       ...
#        2019-09-26 20:00:00+00:00 94            -0.000215  0.000933
#                                  94            -0.000215  0.000933
#                                  94            -0.000215  0.000933
#                                  94            -0.000215  0.000933
#                                  97            -0.000215  0.000933
#
#                                                volume_LAG0  open_LAG1  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                0.539497  -0.000146
#                                  3                0.539497  -0.000146
#                                  6                0.539497  -0.000146
#                                  6                0.539497  -0.000146
#                                  9                0.539497  -0.000146
# ...                                                    ...        ...
#        2019-09-26 20:00:00+00:00 94               4.762202   0.000932
#                                  94               4.762202   0.000932
#                                  94               4.762202   0.000932
#                                  94               4.762202   0.000932
#                                  97               4.762202   0.000932
#
#                                                close_LAG1  high_LAG1  ...  \
# ticker time                      news_horizon                         ...
# MSFT   2019-08-30 15:08:00+00:00 3              -0.000219  -0.000292  ...
#                                  3              -0.000219  -0.000292  ...
#                                  6              -0.000219  -0.000292  ...
#                                  6              -0.000219  -0.000292  ...
#                                  9              -0.000219  -0.000292  ...
# ...                                                   ...        ...  ...
#        2019-09-26 20:00:00+00:00 94              0.000143   0.001218  ...
#                                  94              0.000143   0.001218  ...
#                                  94              0.000143   0.001218  ...
#                                  94              0.000143   0.001218  ...
#                                  97              0.000143   0.001218  ...
#
#                                                volume_LAG99  open_LAG100  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                 9.611399    -0.000359
#                                  3                 9.611399    -0.000359
#                                  6                 9.611399    -0.000359
#                                  6                 9.611399    -0.000359
#                                  9                 9.611399    -0.000359
# ...                                                     ...          ...
#        2019-09-26 20:00:00+00:00 94               -0.407206     0.000644
#                                  94               -0.407206     0.000644
#                                  94               -0.407206     0.000644
#                                  94               -0.407206     0.000644
#                                  97               -0.407206     0.000644
#
#                                                close_LAG100  high_LAG100  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                 0.000647    -0.000072
#                                  3                 0.000647    -0.000072
#                                  6                 0.000647    -0.000072
#                                  6                 0.000647    -0.000072
#                                  9                 0.000647    -0.000072
# ...                                                     ...          ...
#        2019-09-26 20:00:00+00:00 94               -0.000143     0.000215
#                                  94               -0.000143     0.000215
#                                  94               -0.000143     0.000215
#                                  94               -0.000143     0.000215
#                                  97               -0.000143     0.000215
#
#                                                low_LAG100  volume_LAG100  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                0.00036      18.300000
#                                  3                0.00036      18.300000
#                                  6                0.00036      18.300000
#                                  6                0.00036      18.300000
#                                  9                0.00036      18.300000
# ...                                                   ...            ...
#        2019-09-26 20:00:00+00:00 94               0.00043       0.827525
#                                  94               0.00043       0.827525
#                                  94               0.00043       0.827525
#                                  94               0.00043       0.827525
#                                  97               0.00043       0.827525
#
#                                                    id  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             165358
#                                  3             165350
#                                  6             165205
#                                  6             165253
#                                  9             165103
# ...                                               ...
#        2019-09-26 20:00:00+00:00 94            383553
#                                  94            383482
#                                  94            383461
#                                  94            383481
#                                  97            383371
#
#                                                                                            title  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             From Jedis to astronauts: How NASA tapped a vi...
#                                  3             How About a Mash Up of Green Bonds and Century...
#                                  6             Brexit endgame: It's PM Johnson vs parliament ...
#                                  6             The Latest: Scottish court moves up case on UK...
#                                  9             Deutsche Post sees interest from potential Str...
# ...                                                                                          ...
#        2019-09-26 20:00:00+00:00 94            Timeline: The alarming pattern of actions by T...
#                                  94            UK royals give Boaty McBoatface polar ship its...
#                                  94            UPDATE 1-Unipec replaces ship charters after U...
#                                  94            Ukrainian leader's rivals use Trump call to ki...
#                                  97            Pelosi on Trump whistleblower complaint: 'This...
#
#                                                news_horizon  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                        3
#                                  3                        3
#                                  6                        6
#                                  6                        6
#                                  9                        9
# ...                                                     ...
#        2019-09-26 20:00:00+00:00 94                      94
#                                  94                      94
#                                  94                      94
#                                  94                      94
#                                  97                      97
#
#                                                                news_time
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             2019-08-30 15:05:00+00:00
#                                  3             2019-08-30 15:05:00+00:00
#                                  6             2019-08-30 15:02:00+00:00
#                                  6             2019-08-30 15:02:00+00:00
#                                  9             2019-08-30 14:59:00+00:00
# ...                                                                  ...
#        2019-09-26 20:00:00+00:00 94            2019-09-26 18:26:00+00:00
#                                  94            2019-09-26 18:26:00+00:00
#                                  94            2019-09-26 18:26:00+00:00
#                                  94            2019-09-26 18:26:00+00:00
#                                  97            2019-09-26 18:23:00+00:00
#
# [163925 rows x 511 columns]

# %%
tsi_names = ['news_time']
y_names = ['open_LAG0']
removes = ['ticker', 'time', 'id', 'title', 'news_time']

report = golags(tsi_names, y_names, removes, n_folds=5)
report
# Out:
# Fold shape: (21483, 501)
# Test shape: (36978, 501)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-5a71d7ca5c2b> in <module>
#       3 removes = ['ticker', 'time', 'id', 'title', 'news_time']
#       4
# ----> 5 report = golags(tsi_names, y_names, removes, n_folds=5)
#       6 report
#
# <ipython-input-18-47822b7d59ff> in golags(tsi_names, y_names, removes, test_rate, n_folds)
#      11
#      12             model_ = model(**params)
# ---> 13             model_.fit(X_train[j], Y_train[j].ravel())
#      14             Y_hat_train = model_.predict(X_train[j])
#      15             Y_hat_test = model_.predict(X_test)
#
# E:\venv\financial_news_re\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     375             # parallel_backend contexts set at a higher level,
#     376             # since correctness does not rely on using threads.
# --> 377             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     378                              **_joblib_parallel_args(prefer='threads'))(
#     379                 delayed(_parallel_build_trees)(
#
# E:\venv\financial_news_re\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1040
#    1041             with self._backend.retrieval_context():
# -> 1042                 self.retrieve()
#    1043             # Make sure that we get a last message telling us we are done
#    1044             elapsed_time = time.time() - self._start_time
#
# E:\venv\financial_news_re\lib\site-packages\joblib\parallel.py in retrieve(self)
#     919             try:
#     920                 if getattr(self._backend, 'supports_timeout', False):
# --> 921                     self._output.extend(job.get(timeout=self.timeout))
#     922                 else:
#     923                     self._output.extend(job.get())
#
# E:\venv\financial_news_re\lib\multiprocessing\pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# E:\venv\financial_news_re\lib\multiprocessing\pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# E:\venv\financial_news_re\lib\threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# E:\venv\financial_news_re\lib\threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:
