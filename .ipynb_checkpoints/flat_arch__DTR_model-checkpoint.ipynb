# %%
#

# %%
import json
import time
import numpy
import pandas
import datetime

# %%
from sklearn.tree import DecisionTreeRegressor as DTR

# %%
from thats_the_stuff import golags

# %%
# models
# all of them are stored in .json file with possible parameters

import json

with open('./models_params.json') as f:
    models_params = json.load(f)

# %%
def multiply_params(params):
    keys = numpy.array(list(params.keys()))
    dims = numpy.array([len(params[keys[j]]) for j in numpy.arange(keys.shape[0])])
    result = []
    for j in numpy.arange(dims.prod()):
        curr = j
        res = {}
        for k in numpy.arange(keys.shape[0]):
            ix = curr % dims[k]
            res[keys[k]] = params[keys[k]][ix]
            curr = curr // dims[k]
        result.append(res)
    return result

# %%
dim_models = 0
multiple_model_args = multiply_params(models_params['DecisionTreeRegressor'])
multiple_model_args
# Out:
# [{'splitter': 'best', 'max_depth': None, 'max_features': 'auto'},
#  {'splitter': 'random', 'max_depth': None, 'max_features': 'auto'},
#  {'splitter': 'best', 'max_depth': 10, 'max_features': 'auto'},
#  {'splitter': 'random', 'max_depth': 10, 'max_features': 'auto'},
#  {'splitter': 'best', 'max_depth': 5, 'max_features': 'auto'},
#  {'splitter': 'random', 'max_depth': 5, 'max_features': 'auto'},
#  {'splitter': 'best', 'max_depth': 2, 'max_features': 'auto'},
#  {'splitter': 'random', 'max_depth': 2, 'max_features': 'auto'},
#  {'splitter': 'best', 'max_depth': None, 'max_features': 'sqrt'},
#  {'splitter': 'random', 'max_depth': None, 'max_features': 'sqrt'},
#  {'splitter': 'best', 'max_depth': 10, 'max_features': 'sqrt'},
#  {'splitter': 'random', 'max_depth': 10, 'max_features': 'sqrt'},
#  {'splitter': 'best', 'max_depth': 5, 'max_features': 'sqrt'},
#  {'splitter': 'random', 'max_depth': 5, 'max_features': 'sqrt'},
#  {'splitter': 'best', 'max_depth': 2, 'max_features': 'sqrt'},
#  {'splitter': 'random', 'max_depth': 2, 'max_features': 'sqrt'},
#  {'splitter': 'best', 'max_depth': None, 'max_features': 'log2'},
#  {'splitter': 'random', 'max_depth': None, 'max_features': 'log2'},
#  {'splitter': 'best', 'max_depth': 10, 'max_features': 'log2'},
#  {'splitter': 'random', 'max_depth': 10, 'max_features': 'log2'},
#  {'splitter': 'best', 'max_depth': 5, 'max_features': 'log2'},
#  {'splitter': 'random', 'max_depth': 5, 'max_features': 'log2'},
#  {'splitter': 'best', 'max_depth': 2, 'max_features': 'log2'},
#  {'splitter': 'random', 'max_depth': 2, 'max_features': 'log2'}]

# %%
d = './dataset.csv'
data = pandas.read_csv(d)
data = data.rename(columns={'lag': 'news_horizon'})
data = data.set_index(['ticker', 'time', 'news_horizon'], drop=False)
data = data.sort_index()
data
# Out:
#                                               ticker  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3              MSFT
#                                  3              MSFT
#                                  6              MSFT
#                                  6              MSFT
#                                  9              MSFT
# ...                                              ...
#        2019-09-26 20:00:00+00:00 94             MSFT
#                                  94             MSFT
#                                  94             MSFT
#                                  94             MSFT
#                                  97             MSFT
#
#                                                                     time  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             2019-08-30 15:08:00+00:00
#                                  3             2019-08-30 15:08:00+00:00
#                                  6             2019-08-30 15:08:00+00:00
#                                  6             2019-08-30 15:08:00+00:00
#                                  9             2019-08-30 15:08:00+00:00
# ...                                                                  ...
#        2019-09-26 20:00:00+00:00 94            2019-09-26 20:00:00+00:00
#                                  94            2019-09-26 20:00:00+00:00
#                                  94            2019-09-26 20:00:00+00:00
#                                  94            2019-09-26 20:00:00+00:00
#                                  97            2019-09-26 20:00:00+00:00
#
#                                                open_LAG0  close_LAG0  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             -0.000292   -0.000438
#                                  3             -0.000292   -0.000438
#                                  6             -0.000292   -0.000438
#                                  6             -0.000292   -0.000438
#                                  9             -0.000292   -0.000438
# ...                                                  ...         ...
#        2019-09-26 20:00:00+00:00 94            -0.000072    0.000716
#                                  94            -0.000072    0.000716
#                                  94            -0.000072    0.000716
#                                  94            -0.000072    0.000716
#                                  97            -0.000072    0.000716
#
#                                                high_LAG0  low_LAG0  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             -0.000365 -0.000511
#                                  3             -0.000365 -0.000511
#                                  6             -0.000365 -0.000511
#                                  6             -0.000365 -0.000511
#                                  9             -0.000365 -0.000511
# ...                                                  ...       ...
#        2019-09-26 20:00:00+00:00 94            -0.000215  0.000933
#                                  94            -0.000215  0.000933
#                                  94            -0.000215  0.000933
#                                  94            -0.000215  0.000933
#                                  97            -0.000215  0.000933
#
#                                                volume_LAG0  open_LAG1  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                0.539497  -0.000146
#                                  3                0.539497  -0.000146
#                                  6                0.539497  -0.000146
#                                  6                0.539497  -0.000146
#                                  9                0.539497  -0.000146
# ...                                                    ...        ...
#        2019-09-26 20:00:00+00:00 94               4.762202   0.000932
#                                  94               4.762202   0.000932
#                                  94               4.762202   0.000932
#                                  94               4.762202   0.000932
#                                  97               4.762202   0.000932
#
#                                                close_LAG1  high_LAG1  ...  \
# ticker time                      news_horizon                         ...
# MSFT   2019-08-30 15:08:00+00:00 3              -0.000219  -0.000292  ...
#                                  3              -0.000219  -0.000292  ...
#                                  6              -0.000219  -0.000292  ...
#                                  6              -0.000219  -0.000292  ...
#                                  9              -0.000219  -0.000292  ...
# ...                                                   ...        ...  ...
#        2019-09-26 20:00:00+00:00 94              0.000143   0.001218  ...
#                                  94              0.000143   0.001218  ...
#                                  94              0.000143   0.001218  ...
#                                  94              0.000143   0.001218  ...
#                                  97              0.000143   0.001218  ...
#
#                                                volume_LAG99  open_LAG100  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                 9.611399    -0.000359
#                                  3                 9.611399    -0.000359
#                                  6                 9.611399    -0.000359
#                                  6                 9.611399    -0.000359
#                                  9                 9.611399    -0.000359
# ...                                                     ...          ...
#        2019-09-26 20:00:00+00:00 94               -0.407206     0.000644
#                                  94               -0.407206     0.000644
#                                  94               -0.407206     0.000644
#                                  94               -0.407206     0.000644
#                                  97               -0.407206     0.000644
#
#                                                close_LAG100  high_LAG100  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                 0.000647    -0.000072
#                                  3                 0.000647    -0.000072
#                                  6                 0.000647    -0.000072
#                                  6                 0.000647    -0.000072
#                                  9                 0.000647    -0.000072
# ...                                                     ...          ...
#        2019-09-26 20:00:00+00:00 94               -0.000143     0.000215
#                                  94               -0.000143     0.000215
#                                  94               -0.000143     0.000215
#                                  94               -0.000143     0.000215
#                                  97               -0.000143     0.000215
#
#                                                low_LAG100  volume_LAG100  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                0.00036      18.300000
#                                  3                0.00036      18.300000
#                                  6                0.00036      18.300000
#                                  6                0.00036      18.300000
#                                  9                0.00036      18.300000
# ...                                                   ...            ...
#        2019-09-26 20:00:00+00:00 94               0.00043       0.827525
#                                  94               0.00043       0.827525
#                                  94               0.00043       0.827525
#                                  94               0.00043       0.827525
#                                  97               0.00043       0.827525
#
#                                                    id  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             165358
#                                  3             165350
#                                  6             165205
#                                  6             165253
#                                  9             165103
# ...                                               ...
#        2019-09-26 20:00:00+00:00 94            383553
#                                  94            383482
#                                  94            383461
#                                  94            383481
#                                  97            383371
#
#                                                                                            title  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             From Jedis to astronauts: How NASA tapped a vi...
#                                  3             How About a Mash Up of Green Bonds and Century...
#                                  6             Brexit endgame: It's PM Johnson vs parliament ...
#                                  6             The Latest: Scottish court moves up case on UK...
#                                  9             Deutsche Post sees interest from potential Str...
# ...                                                                                          ...
#        2019-09-26 20:00:00+00:00 94            Timeline: The alarming pattern of actions by T...
#                                  94            UK royals give Boaty McBoatface polar ship its...
#                                  94            UPDATE 1-Unipec replaces ship charters after U...
#                                  94            Ukrainian leader's rivals use Trump call to ki...
#                                  97            Pelosi on Trump whistleblower complaint: 'This...
#
#                                                news_horizon  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                        3
#                                  3                        3
#                                  6                        6
#                                  6                        6
#                                  9                        9
# ...                                                     ...
#        2019-09-26 20:00:00+00:00 94                      94
#                                  94                      94
#                                  94                      94
#                                  94                      94
#                                  97                      97
#
#                                                                news_time
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             2019-08-30 15:05:00+00:00
#                                  3             2019-08-30 15:05:00+00:00
#                                  6             2019-08-30 15:02:00+00:00
#                                  6             2019-08-30 15:02:00+00:00
#                                  9             2019-08-30 14:59:00+00:00
# ...                                                                  ...
#        2019-09-26 20:00:00+00:00 94            2019-09-26 18:26:00+00:00
#                                  94            2019-09-26 18:26:00+00:00
#                                  94            2019-09-26 18:26:00+00:00
#                                  94            2019-09-26 18:26:00+00:00
#                                  97            2019-09-26 18:23:00+00:00
#
# [163925 rows x 511 columns]

# %%
tsi_names = ['news_time']
y_names = ['open_LAG0']
removes = ['ticker', 'time', 'id', 'title', 'news_time']

report = golags(DTR, data, multiple_model_args, tsi_names, y_names, removes, n_folds=5)
report
# Out:
# Fold shape: (21483, 501)
# Test shape: (36978, 501)
# N of expected iters = 24
# Started search: 2020-06-15T23:04:53.849456
# 0 / 24
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-30e1a109076a> in <module>
#       3 removes = ['ticker', 'time', 'id', 'title', 'news_time']
#       4
# ----> 5 report = golags(DTR, data, multiple_model_args, tsi_names, y_names, removes, n_folds=5)
#       6 report
#
# C:\Sygm\RAMP\IP-02\OSTRTA\financial_news_re\thats_the_stuff.py in golags(das_model, data, multiple_model_args, tsi_names, y_names, removes, test_rate, n_folds)
#      47
#      48             model_ = das_model(**params)
# ---> 49             model_.fit(X_train[j], Y_train[j].ravel())
#      50             Y_hat_train = model_.predict(X_train[j])
#      51             Y_hat_test = model_.predict(X_test)
#
# E:\venv\financial_news_re\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1219         """
#    1220
# -> 1221         super().fit(
#    1222             X, y,
#    1223             sample_weight=sample_weight,
#
# E:\venv\financial_news_re\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     365                                            min_impurity_split)
#     366
# --> 367         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     368
#     369         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:
