# %%
#

# %%
import json
import time
import numpy
import pandas
import datetime
from scipy import stats
from data.flat import load
from matplotlib import pyplot
from matplotlib import lines as mlines

# %%
# from mpydge.wrap.models.linear import LBR
from lightgbm import LGBMRegressor as LBR

# %%
from m_utils.measures import r2_adj
from m_utils.sampling import ts_sampler
from m_utils.feature_selection import recursive_batch

# %%
# models
# all of them are stored in .json file with possible parameters

import json

with open('./models_params.json') as f:
    models_params = json.load(f)

# %%
def multiply_params(params):
    keys = numpy.array(list(params.keys()))
    dims = numpy.array([len(params[keys[j]]) for j in numpy.arange(keys.shape[0])])
    result = []
    for j in numpy.arange(dims.prod()):
        curr = j
        res = {}
        for k in numpy.arange(keys.shape[0]):
            ix = curr % dims[k]
            res[keys[k]] = params[keys[k]][ix]
            curr = curr // dims[k]
        result.append(res)
    return result

# %%
dim_models = 0
multiple_model_args = multiply_params(models_params['LGBMRegressor'])
multiple_model_args
# Out:
# [{'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 0.95,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 0.9,
#   'reg_alpha': 0.0,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
# ...
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 200,
#   'class_weight': None,
#   'subsample': 1.0,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 10,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 50,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.1,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.5,
#   'n_estimators': 100,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': -1,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 10,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 5,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  {'max_depth': 2,
#   'learning_rate': 0.01,
#   'n_estimators': 200,
#   'class_weight': 'balanced',
#   'subsample': 0.95,
#   'reg_alpha': 0.5,
#   'reg_lambda': 0.0,
#   'n_jobs': -1},
#  ...]

# %%
def load_data(data, tsi_names, y_names, removes, test_rate, n_folds):

    # clarify names

    exclude = y_names + removes
    x_names = [x for x in data.columns.values if (x not in exclude and 'LAG0' not in x)]
    
    # sample (without folds)

    data_train, data_test = ts_sampler(data, n_folds, test_rate)
    X_, Y_ = numpy.array(x_names), numpy.array(y_names)
    X_train, Y_train = [x[X_].values for x in data_train], [x[Y_].values for x in data_train]
    X_test, Y_test = data_test[X_].values, data_test[Y_].values
    
    print('Fold shape: {0}'.format(X_train[0].shape))
    print('Test shape: {0}'.format(X_test.shape))
    
    return X_train, Y_train, X_test, Y_test, X_

# %%
def golags(tsi_names, y_names, removes, test_rate=0.2, n_folds=1):
    report = pandas.DataFrame(columns=['Np', 'Nf', 'R2_adj_train', 'R2_adj_test', 'd1', 'params', 'd1', 'X_adj_'])
    X_train, Y_train, X_test, Y_test, X_ = load_data(data, tsi_names, y_names, removes, test_rate, n_folds)
    model = LBR

    verbose_step = 100
    n_iters = len(multiple_model_args)
    print('N of expected iters = {0}'.format(n_iters))
    print('Started search: {0}'.format(datetime.datetime.now().isoformat()))
    
    for i in range(len(multiple_model_args)):
        
        if i % verbose_step == 0:
            print('{0} / {1}'.format(i, n_iters))
        
        params = multiple_model_args[i]
        
        for j in range(len(X_train)):
            
            model_ = model(**params)
            model_.fit(X_train[j], Y_train[j].ravel())
            Y_hat_train = model_.predict(X_train[j])
            Y_hat_test = model_.predict(X_test)
            result = {'Np': i, 'Nf': j, 
                      'R2_adj_train': r2_adj(Y_train[j], Y_hat_train, X_train[j].shape[0], X_train[j].shape[1]),
                      'R2_adj_test': r2_adj(Y_test, Y_hat_test, X_test.shape[0], X_test.shape[1]),
                      'd1': X_train[j].shape[1], 'params': params, 'X_adj_': X_}
            
            report = report.append(result, ignore_index=True)

    print('Finished search: {0}'.format(datetime.datetime.now().isoformat()))
    
    return report

# %%
d = './dataset.csv'
data = pandas.read_csv(d)
data = data.rename(columns={'lag': 'news_horizon'})
data = data.set_index(['ticker', 'time', 'news_horizon'], drop=False)
data = data.sort_index()
data
# Out:
#                                               ticker  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3              MSFT
#                                  3              MSFT
#                                  6              MSFT
#                                  6              MSFT
#                                  9              MSFT
# ...                                              ...
#        2019-09-26 20:00:00+00:00 94             MSFT
#                                  94             MSFT
#                                  94             MSFT
#                                  94             MSFT
#                                  97             MSFT
#
#                                                                     time  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             2019-08-30 15:08:00+00:00
#                                  3             2019-08-30 15:08:00+00:00
#                                  6             2019-08-30 15:08:00+00:00
#                                  6             2019-08-30 15:08:00+00:00
#                                  9             2019-08-30 15:08:00+00:00
# ...                                                                  ...
#        2019-09-26 20:00:00+00:00 94            2019-09-26 20:00:00+00:00
#                                  94            2019-09-26 20:00:00+00:00
#                                  94            2019-09-26 20:00:00+00:00
#                                  94            2019-09-26 20:00:00+00:00
#                                  97            2019-09-26 20:00:00+00:00
#
#                                                open_LAG0  close_LAG0  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             -0.000292   -0.000438
#                                  3             -0.000292   -0.000438
#                                  6             -0.000292   -0.000438
#                                  6             -0.000292   -0.000438
#                                  9             -0.000292   -0.000438
# ...                                                  ...         ...
#        2019-09-26 20:00:00+00:00 94            -0.000072    0.000716
#                                  94            -0.000072    0.000716
#                                  94            -0.000072    0.000716
#                                  94            -0.000072    0.000716
#                                  97            -0.000072    0.000716
#
#                                                high_LAG0  low_LAG0  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             -0.000365 -0.000511
#                                  3             -0.000365 -0.000511
#                                  6             -0.000365 -0.000511
#                                  6             -0.000365 -0.000511
#                                  9             -0.000365 -0.000511
# ...                                                  ...       ...
#        2019-09-26 20:00:00+00:00 94            -0.000215  0.000933
#                                  94            -0.000215  0.000933
#                                  94            -0.000215  0.000933
#                                  94            -0.000215  0.000933
#                                  97            -0.000215  0.000933
#
#                                                volume_LAG0  open_LAG1  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                0.539497  -0.000146
#                                  3                0.539497  -0.000146
#                                  6                0.539497  -0.000146
#                                  6                0.539497  -0.000146
#                                  9                0.539497  -0.000146
# ...                                                    ...        ...
#        2019-09-26 20:00:00+00:00 94               4.762202   0.000932
#                                  94               4.762202   0.000932
#                                  94               4.762202   0.000932
#                                  94               4.762202   0.000932
#                                  97               4.762202   0.000932
#
#                                                close_LAG1  high_LAG1  ...  \
# ticker time                      news_horizon                         ...
# MSFT   2019-08-30 15:08:00+00:00 3              -0.000219  -0.000292  ...
#                                  3              -0.000219  -0.000292  ...
#                                  6              -0.000219  -0.000292  ...
#                                  6              -0.000219  -0.000292  ...
#                                  9              -0.000219  -0.000292  ...
# ...                                                   ...        ...  ...
#        2019-09-26 20:00:00+00:00 94              0.000143   0.001218  ...
#                                  94              0.000143   0.001218  ...
#                                  94              0.000143   0.001218  ...
#                                  94              0.000143   0.001218  ...
#                                  97              0.000143   0.001218  ...
#
#                                                volume_LAG99  open_LAG100  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                 9.611399    -0.000359
#                                  3                 9.611399    -0.000359
#                                  6                 9.611399    -0.000359
#                                  6                 9.611399    -0.000359
#                                  9                 9.611399    -0.000359
# ...                                                     ...          ...
#        2019-09-26 20:00:00+00:00 94               -0.407206     0.000644
#                                  94               -0.407206     0.000644
#                                  94               -0.407206     0.000644
#                                  94               -0.407206     0.000644
#                                  97               -0.407206     0.000644
#
#                                                close_LAG100  high_LAG100  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                 0.000647    -0.000072
#                                  3                 0.000647    -0.000072
#                                  6                 0.000647    -0.000072
#                                  6                 0.000647    -0.000072
#                                  9                 0.000647    -0.000072
# ...                                                     ...          ...
#        2019-09-26 20:00:00+00:00 94               -0.000143     0.000215
#                                  94               -0.000143     0.000215
#                                  94               -0.000143     0.000215
#                                  94               -0.000143     0.000215
#                                  97               -0.000143     0.000215
#
#                                                low_LAG100  volume_LAG100  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                0.00036      18.300000
#                                  3                0.00036      18.300000
#                                  6                0.00036      18.300000
#                                  6                0.00036      18.300000
#                                  9                0.00036      18.300000
# ...                                                   ...            ...
#        2019-09-26 20:00:00+00:00 94               0.00043       0.827525
#                                  94               0.00043       0.827525
#                                  94               0.00043       0.827525
#                                  94               0.00043       0.827525
#                                  97               0.00043       0.827525
#
#                                                    id  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             165358
#                                  3             165350
#                                  6             165205
#                                  6             165253
#                                  9             165103
# ...                                               ...
#        2019-09-26 20:00:00+00:00 94            383553
#                                  94            383482
#                                  94            383461
#                                  94            383481
#                                  97            383371
#
#                                                                                            title  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             From Jedis to astronauts: How NASA tapped a vi...
#                                  3             How About a Mash Up of Green Bonds and Century...
#                                  6             Brexit endgame: It's PM Johnson vs parliament ...
#                                  6             The Latest: Scottish court moves up case on UK...
#                                  9             Deutsche Post sees interest from potential Str...
# ...                                                                                          ...
#        2019-09-26 20:00:00+00:00 94            Timeline: The alarming pattern of actions by T...
#                                  94            UK royals give Boaty McBoatface polar ship its...
#                                  94            UPDATE 1-Unipec replaces ship charters after U...
#                                  94            Ukrainian leader's rivals use Trump call to ki...
#                                  97            Pelosi on Trump whistleblower complaint: 'This...
#
#                                                news_horizon  \
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3                        3
#                                  3                        3
#                                  6                        6
#                                  6                        6
#                                  9                        9
# ...                                                     ...
#        2019-09-26 20:00:00+00:00 94                      94
#                                  94                      94
#                                  94                      94
#                                  94                      94
#                                  97                      97
#
#                                                                news_time
# ticker time                      news_horizon
# MSFT   2019-08-30 15:08:00+00:00 3             2019-08-30 15:05:00+00:00
#                                  3             2019-08-30 15:05:00+00:00
#                                  6             2019-08-30 15:02:00+00:00
#                                  6             2019-08-30 15:02:00+00:00
#                                  9             2019-08-30 14:59:00+00:00
# ...                                                                  ...
#        2019-09-26 20:00:00+00:00 94            2019-09-26 18:26:00+00:00
#                                  94            2019-09-26 18:26:00+00:00
#                                  94            2019-09-26 18:26:00+00:00
#                                  94            2019-09-26 18:26:00+00:00
#                                  97            2019-09-26 18:23:00+00:00
#
# [163925 rows x 511 columns]

# %%
tsi_names = ['news_time']
y_names = ['open_LAG0']
removes = ['ticker', 'time', 'id', 'title', 'news_time']

report = golags(tsi_names, y_names, removes, n_folds=5)
report
# Out:
# Fold shape: (21483, 501)
# Test shape: (36978, 501)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-5a71d7ca5c2b> in <module>
#       3 removes = ['ticker', 'time', 'id', 'title', 'news_time']
#       4
# ----> 5 report = golags(tsi_names, y_names, removes, n_folds=5)
#       6 report
#
# <ipython-input-19-9bdeebd05b53> in golags(tsi_names, y_names, removes, test_rate, n_folds)
#      11
#      12             model_ = model(**params)
# ---> 13             model_.fit(X_train[j], Y_train[j].ravel())
#      14             Y_hat_train = model_.predict(X_train[j])
#      15             Y_hat_test = model_.predict(X_test)
#
# E:\venv\financial_news_re\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     727             verbose=True, feature_name='auto', categorical_feature='auto', callbacks=None):
#     728         """Docstring is inherited from the LGBMModel."""
# --> 729         super(LGBMRegressor, self).fit(X, y, sample_weight=sample_weight,
#     730                                        init_score=init_score, eval_set=eval_set,
#     731                                        eval_names=eval_names,
#
# E:\venv\financial_news_re\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     587                 valid_sets.append(valid_set)
#     588
# --> 589         self._Booster = train(params, train_set,
#     590                               self.n_estimators, valid_sets=valid_sets, valid_names=eval_names,
#     591                               early_stopping_rounds=early_stopping_rounds,
#
# E:\venv\financial_news_re\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     226     # construct booster
#     227     try:
# --> 228         booster = Booster(params=params, train_set=train_set)
#     229         if is_valid_contain_train:
#     230             booster.set_train_data_name(train_data_name)
#
# E:\venv\financial_news_re\lib\site-packages\lightgbm\basic.py in __init__(self, params, train_set, model_file, model_str, silent)
#    1662             self.handle = ctypes.c_void_p()
#    1663             _safe_call(_LIB.LGBM_BoosterCreate(
# -> 1664                 train_set.construct().handle,
#    1665                 c_str(params_str),
#    1666                 ctypes.byref(self.handle)))
#
# E:\venv\financial_news_re\lib\site-packages\lightgbm\basic.py in construct(self)
#    1031             else:
#    1032                 # create train
# -> 1033                 self._lazy_init(self.data, label=self.label,
#    1034                                 weight=self.weight, group=self.group,
#    1035                                 init_score=self.init_score, predictor=self._predictor,
#
# E:\venv\financial_news_re\lib\site-packages\lightgbm\basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#     837             self.__init_from_csc(data, params_str, ref_dataset)
#     838         elif isinstance(data, np.ndarray):
# --> 839             self.__init_from_np2d(data, params_str, ref_dataset)
#     840         elif isinstance(data, list) and len(data) > 0 and all(isinstance(x, np.ndarray) for x in data):
#     841             self.__init_from_list_np2d(data, params_str, ref_dataset)
#
# E:\venv\financial_news_re\lib\site-packages\lightgbm\basic.py in __init_from_np2d(self, mat, params_str, ref_dataset)
#     879
#     880         ptr_data, type_ptr_data, _ = c_float_array(data)
# --> 881         _safe_call(_LIB.LGBM_DatasetCreateFromMat(
#     882             ptr_data,
#     883             ctypes.c_int(type_ptr_data),
#
# KeyboardInterrupt:
