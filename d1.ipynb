# %%
import json
import time
import numpy
import pandas
from data.flat import load
# Out:
# E:\venv\financial_news_re\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
k = 'C:/Users/MainUser/Desktop/OpenAPI_sandbox.txt'
crs = open(k, "r")
for columns in ( raw.strip().split() for raw in crs ):
    api_key = columns[0]

# %%
target_quotes = ['MSFT']
news_horizon = 100
effect_horizon = 10

# %%
data = await load(api_key, target_quotes, news_horizon, effect_horizon)
data
# Out:
# E:\venv\financial_news_re\lib\site-packages\pandas\core\arrays\datetimelike.py:1265: PerformanceWarning: Adding/subtracting array of DateOffsets to DatetimeArray not vectorized
#   warnings.warn(
# 2019-08-29 22:27:30.057000
# 2019-10-05 08:07:58.138000
# (51788, 57)
# Index(['ticker', 'time', 'open_HOZ0_PCT1', 'close_HOZ0_PCT1', 'high_HOZ0_PCT1',
#        'low_HOZ0_PCT1', 'volume_HOZ0_PCT1', 'open_HOZ1_PCT1',
#        'close_HOZ1_PCT1', 'high_HOZ1_PCT1', 'low_HOZ1_PCT1',
#        'volume_HOZ1_PCT1', 'open_HOZ2_PCT1', 'close_HOZ2_PCT1',
#        'high_HOZ2_PCT1', 'low_HOZ2_PCT1', 'volume_HOZ2_PCT1', 'open_HOZ3_PCT1',
#        'close_HOZ3_PCT1', 'high_HOZ3_PCT1', 'low_HOZ3_PCT1',
#        'volume_HOZ3_PCT1', 'open_HOZ4_PCT1', 'close_HOZ4_PCT1',
#        'high_HOZ4_PCT1', 'low_HOZ4_PCT1', 'volume_HOZ4_PCT1', 'open_HOZ5_PCT1',
#        'close_HOZ5_PCT1', 'high_HOZ5_PCT1', 'low_HOZ5_PCT1',
#        'volume_HOZ5_PCT1', 'open_HOZ6_PCT1', 'close_HOZ6_PCT1',
#        'high_HOZ6_PCT1', 'low_HOZ6_PCT1', 'volume_HOZ6_PCT1', 'open_HOZ7_PCT1',
#        'close_HOZ7_PCT1', 'high_HOZ7_PCT1', 'low_HOZ7_PCT1',
#        'volume_HOZ7_PCT1', 'open_HOZ8_PCT1', 'close_HOZ8_PCT1',
#        'high_HOZ8_PCT1', 'low_HOZ8_PCT1', 'volume_HOZ8_PCT1', 'open_HOZ9_PCT1',
#        'close_HOZ9_PCT1', 'high_HOZ9_PCT1', 'low_HOZ9_PCT1',
#        'volume_HOZ9_PCT1', 'open_HOZ10_PCT1', 'close_HOZ10_PCT1',
#        'high_HOZ10_PCT1', 'low_HOZ10_PCT1', 'volume_HOZ10_PCT1'],
#       dtype='object')
#       ticker                      time  open_HOZ0_PCT1  close_HOZ0_PCT1  \
# 0       MSFT 2019-08-29 22:50:00+00:00             NaN              NaN
# 1       MSFT 2019-08-29 22:51:00+00:00             NaN              NaN
# 2       MSFT 2019-08-29 22:52:00+00:00             NaN              NaN
# 3       MSFT 2019-08-29 22:53:00+00:00             NaN              NaN
# 4       MSFT 2019-08-29 22:54:00+00:00             NaN              NaN
# ...      ...                       ...             ...              ...
# 51783   MSFT 2019-10-04 21:53:00+00:00             NaN              NaN
# 51784   MSFT 2019-10-04 21:54:00+00:00             NaN              NaN
# 51785   MSFT 2019-10-04 21:55:00+00:00             NaN              NaN
# 51786   MSFT 2019-10-04 21:56:00+00:00             0.0              0.0
# 51787   MSFT 2019-10-04 21:57:00+00:00             0.0              0.0
#
#        high_HOZ0_PCT1  low_HOZ0_PCT1 volume_HOZ0_PCT1  open_HOZ1_PCT1  \
# 0                 NaN            NaN              NaN             NaN
# 1                 NaN            NaN              NaN             NaN
# 2                 NaN            NaN              NaN             NaN
# 3                 NaN            NaN              NaN             NaN
# 4                 NaN            NaN              NaN             NaN
# ...               ...            ...              ...             ...
# 51783             NaN            NaN              NaN             NaN
# 51784             NaN            NaN              NaN             NaN
# 51785             NaN            NaN              NaN             NaN
# 51786             0.0            0.0        -0.833333             NaN
# 51787             0.0            0.0               13             0.0
#
#        close_HOZ1_PCT1  high_HOZ1_PCT1  ...  open_HOZ9_PCT1 close_HOZ9_PCT1  \
# 0                  NaN             NaN  ...             NaN             NaN
# 1                  NaN             NaN  ...             NaN             NaN
# 2                  NaN             NaN  ...             NaN             NaN
# 3                  NaN             NaN  ...             NaN             NaN
# 4                  NaN             NaN  ...             NaN             NaN
# ...                ...             ...  ...             ...             ...
# 51783              NaN             NaN  ...             NaN             NaN
# 51784              NaN             NaN  ...             NaN             NaN
# 51785              NaN             NaN  ...             NaN             NaN
# 51786              NaN             NaN  ...             NaN             NaN
# 51787              0.0             0.0  ...             NaN             NaN
#
#        high_HOZ9_PCT1  low_HOZ9_PCT1  volume_HOZ9_PCT1  open_HOZ10_PCT1  \
# 0                 NaN            NaN               NaN              NaN
# 1                 NaN            NaN               NaN              NaN
# 2                 NaN            NaN               NaN              NaN
# 3                 NaN            NaN               NaN              NaN
# 4                 NaN            NaN               NaN              NaN
# ...               ...            ...               ...              ...
# 51783             NaN            NaN               NaN              NaN
# 51784             NaN            NaN               NaN              NaN
# 51785             NaN            NaN               NaN              NaN
# 51786             NaN            NaN               NaN              NaN
# 51787             NaN            NaN               NaN              NaN
#
#       close_HOZ10_PCT1  high_HOZ10_PCT1  low_HOZ10_PCT1  volume_HOZ10_PCT1
# 0                  NaN              NaN             NaN                NaN
# 1                  NaN              NaN             NaN                NaN
# 2                  NaN              NaN             NaN                NaN
# 3                  NaN              NaN             NaN                NaN
# 4                  NaN              NaN             NaN                NaN
# ...                ...              ...             ...                ...
# 51783              NaN              NaN             NaN                NaN
# 51784              NaN              NaN             NaN                NaN
# 51785              NaN              NaN             NaN                NaN
# 51786              NaN              NaN             NaN                NaN
# 51787              NaN              NaN             NaN                NaN
#
# [51788 rows x 57 columns]
# (9625,)
#               id                                              title   lag  \
# 0       141465.0  Shares rally, bond yields rise as China fuels ...   4.0
# 1       141465.0  Shares rally, bond yields rise as China fuels ...   5.0
# 2       141465.0  Shares rally, bond yields rise as China fuels ...  12.0
# 3       141465.0  Shares rally, bond yields rise as China fuels ...  20.0
# 4       141465.0  Shares rally, bond yields rise as China fuels ...  22.0
# ...          ...                                                ...   ...
# 993325       NaN                                               None   NaN
# 993326       NaN                                               None   NaN
# 993327       NaN                                               None   NaN
# 993328       NaN                                               None   NaN
# 993329       NaN                                               None   NaN
#
#                      news_time ticker                      time  \
# 0      2019-08-29 22:36:30.057   None                       NaT
# 1      2019-08-29 22:36:30.057   None                       NaT
# 2      2019-08-29 22:36:30.057   None                       NaT
# 3      2019-08-29 22:36:30.057   MSFT 2019-08-29 22:57:00+00:00
# 4      2019-08-29 22:36:30.057   MSFT 2019-08-29 22:59:00+00:00
# ...                        ...    ...                       ...
# 993325                     NaT   MSFT 2019-09-17 23:46:00+00:00
# 993326                     NaT   MSFT 2019-09-05 08:49:00+00:00
# 993327                     NaT   MSFT 2019-09-13 08:19:00+00:00
# 993328                     NaT   MSFT 2019-09-27 21:55:00+00:00
# 993329                     NaT   MSFT 2019-09-02 02:53:00+00:00
#
#         open_HOZ0_PCT1  close_HOZ0_PCT1  high_HOZ0_PCT1  low_HOZ0_PCT1  ...  \
# 0                  NaN              NaN             NaN            NaN  ...
# 1                  NaN              NaN             NaN            NaN  ...
# 2                  NaN              NaN             NaN            NaN  ...
# 3                  NaN              NaN             NaN            NaN  ...
# 4                  NaN              NaN             NaN            NaN  ...
# ...                ...              ...             ...            ...  ...
# 993325             NaN              NaN             NaN            NaN  ...
# 993326             NaN              NaN             NaN            NaN  ...
# 993327             NaN              NaN             NaN            NaN  ...
# 993328        -0.00029         -0.00029        -0.00029       -0.00029  ...
# 993329             NaN              NaN             NaN            NaN  ...
#
#         open_HOZ9_PCT1  close_HOZ9_PCT1  high_HOZ9_PCT1  low_HOZ9_PCT1  \
# 0                  NaN              NaN             NaN            NaN
# 1                  NaN              NaN             NaN            NaN
# 2                  NaN              NaN             NaN            NaN
# 3                  NaN              NaN             NaN            NaN
# 4                  NaN              NaN             NaN            NaN
# ...                ...              ...             ...            ...
# 993325             NaN              NaN             NaN            NaN
# 993326             NaN              NaN             NaN            NaN
# 993327             NaN              NaN             NaN            NaN
# 993328             NaN              NaN             NaN            NaN
# 993329             NaN              NaN             NaN            NaN
#
#         volume_HOZ9_PCT1  open_HOZ10_PCT1  close_HOZ10_PCT1  high_HOZ10_PCT1  \
# 0                    NaN              NaN               NaN              NaN
# 1                    NaN              NaN               NaN              NaN
# 2                    NaN              NaN               NaN              NaN
# 3                    NaN              NaN               NaN              NaN
# 4                    NaN              NaN               NaN              NaN
# ...                  ...              ...               ...              ...
# 993325               NaN              NaN               NaN              NaN
# 993326               NaN              NaN               NaN              NaN
# 993327               NaN              NaN               NaN              NaN
# 993328               NaN              NaN               NaN              NaN
# 993329               NaN              NaN               NaN              NaN
#
#         low_HOZ10_PCT1  volume_HOZ10_PCT1
# 0                  NaN                NaN
# 1                  NaN                NaN
# 2                  NaN                NaN
# 3                  NaN                NaN
# 4                  NaN                NaN
# ...                ...                ...
# 993325             NaN                NaN
# 993326             NaN                NaN
# 993327             NaN                NaN
# 993328             NaN                NaN
# 993329             NaN                NaN
#
# [993330 rows x 61 columns]
