# %%
import json
import time
import numpy
import pandas
from data.flat_sql import Loader
# Out:
# E:\venv\financial_news_re\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
k = 'C:/Users/MainUser/Desktop/OpenAPI_sandbox.txt'
crs = open(k, "r")
for columns in (raw.strip().split() for raw in crs):
    api_key = columns[0]

# %%
target_quotes = ['MSFT']
news_horizon = 100
effect_horizon = 100

# %%
db_config = 'C:/Users/MainUser/Desktop/config.json'
news_titles_source = './data/data/rex.xlsx'

# %%
loader = Loader(api_key, target_quotes, news_horizon, effect_horizon, db_config, reload_quotes=True,
                 news_titles_source=news_titles_source, verbose=True, base_option='without')
# loader = Loader(api_key, target_quotes, news_horizon, effect_horizon, db_config, reload_quotes=False,
#                  news_titles_source=None, verbose=True, base_option='without')

# %%
data = await loader.read()
# Out:
# Reading
# Skipped Connection
# Preparing News Titles Frame
# E:\venv\financial_news_re\lib\site-packages\pandas\core\arrays\datetimelike.py:1265: PerformanceWarning: Adding/subtracting array of DateOffsets to DatetimeArray not vectorized
#   warnings.warn(
# Preparing Quotes
# Getting Dates
# Filling Quotes
# Getting Dates
# Lagging Quotes
# Evaluating Quotes Percents

# %%
data.columns = [x.replace('_PCT1', '') for x in data.columns.values]
data.dropna().sort_values(by=['title', 'lag'])
# Out:
#        ticker                      time  open_LAG01  close_LAG01  high_LAG01  \
# 504096   MSFT 2019-09-23 15:53:00+00:00   -0.000359     0.000072   -0.000287
# 504201   MSFT 2019-09-23 15:54:00+00:00    0.000144     0.000359    0.000502
# 504306   MSFT 2019-09-23 15:55:00+00:00    0.000287     0.000215    0.000072
# 504411   MSFT 2019-09-23 15:56:00+00:00    0.000287     0.000000    0.000215
# 504519   MSFT 2019-09-23 15:57:00+00:00   -0.000072    -0.000143   -0.000143
# ...       ...                       ...         ...          ...         ...
# 508714   MSFT 2019-09-23 16:38:00+00:00    0.000359     0.000000    0.000072
# 508817   MSFT 2019-09-23 16:39:00+00:00   -0.000072     0.000072    0.000000
# 508920   MSFT 2019-09-23 16:40:00+00:00    0.000072    -0.000215   -0.000072
# 509023   MSFT 2019-09-23 16:41:00+00:00   -0.000215     0.000574    0.000359
# 509127   MSFT 2019-09-23 16:42:00+00:00    0.000574     0.000143    0.000215
#
#         low_LAG01 volume_LAG01  open_LAG11  close_LAG11  high_LAG11  ...  \
# 504096  -0.000144     -0.37097   -0.000143    -0.000430   -0.000143  ...
# 504201   0.000359    -0.138693   -0.000359     0.000072   -0.000287  ...
# 504306   0.000215    -0.160793    0.000144     0.000359    0.000502  ...
# 504411   0.000143      0.69188    0.000287     0.000215    0.000072  ...
# 504519   0.000000    -0.357331    0.000287     0.000000    0.000215  ...
# ...           ...          ...         ...          ...         ...  ...
# 508714   0.000287    -0.334942    0.000359     0.000287    0.000359  ...
# 508817   0.000000   -0.0904926    0.000359     0.000000    0.000072  ...
# 508920  -0.000144      1.27036   -0.000072     0.000072    0.000000  ...
# 509023   0.000000    0.0392012    0.000072    -0.000215   -0.000072  ...
# 509127   0.000574    -0.232562   -0.000215     0.000574    0.000359  ...
#
#         volume_LAG991 open_LAG1001  close_LAG1001  high_LAG1001  low_LAG1001  \
# 504096       0.156438     0.000144       0.000361      0.000505     0.000217
# 504201      -0.194598     0.000361       0.000577      0.000361     0.000361
# 504306       0.319666     0.000577       0.000433      0.000649     0.000505
# 504411      -0.100533     0.000577       0.000721      0.000648     0.000649
# 504519      -0.415248     0.000576       0.000504      0.000648     0.000576
# ...               ...          ...            ...           ...          ...
# 508714       0.247223     0.000504      -0.000072     -0.000072     0.000288
# 508817        1.17595    -0.000072       0.000504      0.000288     0.000216
# 508920      -0.529884     0.000576       0.000072      0.000504     0.000216
# 509023      -0.188079     0.000000       0.000000     -0.000431     0.000000
# 509127        2.00399     0.000072       0.000719      0.000791     0.000360
#
#         volume_LAG1001      id  \
# 504096       -0.140647  244575
# 504201        0.156438  244575
# 504306       -0.194598  244575
# 504411        0.319666  244575
# 504519       -0.100533  244575
# ...                ...     ...
# 508714       -0.568541  243148
# 508817        0.247223  243148
# 508920         1.17595  243148
# 509023       -0.529884  243148
# 509127       -0.188079  243148
#
#                                                     title  lag  \
# 504096  "Flash Boys" exchange IEX drops out of corpora...    1
# 504201  "Flash Boys" exchange IEX drops out of corpora...    2
# 504306  "Flash Boys" exchange IEX drops out of corpora...    3
# 504411  "Flash Boys" exchange IEX drops out of corpora...    4
# 504519  "Flash Boys" exchange IEX drops out of corpora...    5
# ...                                                   ...  ...
# 508714  ‘When the president does it, that means it’s n...   95
# 508817  ‘When the president does it, that means it’s n...   96
# 508920  ‘When the president does it, that means it’s n...   97
# 509023  ‘When the president does it, that means it’s n...   98
# 509127  ‘When the president does it, that means it’s n...   99
#
#                        news_time
# 504096 2019-09-23 15:52:00+00:00
# 504201 2019-09-23 15:52:00+00:00
# 504306 2019-09-23 15:52:00+00:00
# 504411 2019-09-23 15:52:00+00:00
# 504519 2019-09-23 15:52:00+00:00
# ...                          ...
# 508714 2019-09-23 15:03:00+00:00
# 508817 2019-09-23 15:03:00+00:00
# 508920 2019-09-23 15:03:00+00:00
# 509023 2019-09-23 15:03:00+00:00
# 509127 2019-09-23 15:03:00+00:00
#
# [163925 rows x 511 columns]

# %%
d = './dataset.csv'
data.dropna().sort_values(by=['title', 'lag']).to_csv(d, index=False)
