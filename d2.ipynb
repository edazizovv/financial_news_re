# %%
import json
import time
import numpy
import pandas
from data.flat_sql import Loader
# Out:
# E:\venv\financial_news_re\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
k = 'C:/Users/MainUser/Desktop/OpenAPI_sandbox.txt'
crs = open(k, "r")
for columns in (raw.strip().split() for raw in crs ):
    api_key = columns[0]

# %%
target_quotes = ['MSFT']
news_horizon = 100
effect_horizon = 10

# %%
db_config = 'C:/Users/MainUser/Desktop/config.json'
news_titles_source = './data/data/rex.xlsx'

# %%
# data = await load(api_key, target_quotes, news_horizon, effect_horizon)
# data
loader = Loader(api_key, target_quotes, news_horizon, effect_horizon, db_config, reload_quotes=True,
                 news_titles_source=news_titles_source, verbose=True)

# %%
data = await loader.read()
# Out:
# Reading
# Establishing Connection
# Preparing News Titles Frame
# Preparing Quotes
# Getting Dates
# Filling Quotes
# Getting Dates
# Lagging Quotes
# Evaluating Quotes Percents

# %%
data.dropna().sort_values(by=['title', 'lag'])
# Out:
#               id                                              title   lag  \
# 114806  142741.0                   "An attractive reference market"  10.0
# 115004  142743.0                           "Cryptovalley meets SDX"  10.0
# 755407  244575.0  "Flash Boys" exchange IEX drops out of corpora...   1.0
# 366952  244575.0  "Flash Boys" exchange IEX drops out of corpora...   2.0
# 366953  244575.0  "Flash Boys" exchange IEX drops out of corpora...   3.0
# ...          ...                                                ...   ...
# 753249  243148.0  ‘When the president does it, that means it’s n...  96.0
# 364655  243148.0  ‘When the president does it, that means it’s n...  97.0
# 364656  243148.0  ‘When the president does it, that means it’s n...  98.0
# 364657  243148.0  ‘When the president does it, that means it’s n...  99.0
# 21732   141702.0  ﬂTrump’s revival of claim of voting fraud in N...  12.0
#
#                      news_time                      time ticker    open  \
# 114806 2019-08-29 22:39:44.655 2019-08-29 22:50:00+00:00   MSFT  138.02
# 115004 2019-08-29 22:39:44.655 2019-08-29 22:50:00+00:00   MSFT  138.02
# 755407 2019-09-23 15:51:34.551 2019-09-23 15:53:00+00:00   MSFT  139.36
# 366952 2019-09-23 15:51:34.551 2019-09-23 15:54:00+00:00   MSFT  139.38
# 366953 2019-09-23 15:51:34.551 2019-09-23 15:55:00+00:00   MSFT  139.42
# ...                        ...                       ...    ...     ...
# 753249 2019-09-23 15:02:53.741 2019-09-23 16:39:00+00:00   MSFT  139.36
# 364655 2019-09-23 15:02:53.741 2019-09-23 16:40:00+00:00   MSFT  139.37
# 364656 2019-09-23 15:02:53.741 2019-09-23 16:41:00+00:00   MSFT  139.34
# 364657 2019-09-23 15:02:53.741 2019-09-23 16:42:00+00:00   MSFT  139.42
# 21732  2019-08-29 22:37:03.469 2019-08-29 22:50:00+00:00   MSFT  138.02
#
#          close    high     low  volume
# 114806  138.02  138.02  138.02    12.0
# 115004  138.02  138.02  138.02    12.0
# 755407  139.37  139.37  139.33  4975.0
# 366952  139.42  139.44  139.38  4285.0
# 366953  139.45  139.45  139.41  3596.0
# ...        ...     ...     ...     ...
# 753249  139.37  139.38  139.36  2382.0
# 364655  139.34  139.37  139.34  5408.0
# 364656  139.42  139.42  139.34  5620.0
# 364657  139.44  139.45  139.42  4313.0
# 21732   138.02  138.02  138.02    12.0
#
# [255623 rows x 11 columns]
